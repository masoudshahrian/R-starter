# %% [markdown]
# <a href="https://www.kaggle.com/code/masoudshahrian/r-starter?scriptVersionId=297564890" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# First install rpy2 (if not already available)
# !pip install rpy2

# Load R extension
# %load_ext rpy2.ipython

# %%
# %%R
# library(ggplot2)
# library(dplyr)
#
# train <- read.csv("/kaggle/input/titanicdataset-traincsv/train.csv")
#
# survival_rate <- train %>%
#   group_by(Sex) %>%
#   summarise(SurvivalRate = mean(Survived, na.rm = TRUE))
#
# print(survival_rate)
#
# ggplot(train, aes(x = Sex, fill = factor(Survived))) +
#   geom_bar(position = "fill") +
#   labs(y = "Proportion", fill = "Survived") +
#   ggtitle("Survival Rate by Sex in Titanic Dataset") +
#   theme_minimal()
# Out:
# # A tibble: 2 × 2
#   Sex    SurvivalRate
#   <chr>         <dbl>
# 1 female        0.742
# 2 male          0.189
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
