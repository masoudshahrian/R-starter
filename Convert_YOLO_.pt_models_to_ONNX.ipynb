# %% [markdown]
# <a href="https://colab.research.google.com/github/masoudshahrian/R-starter/blob/main/Convert_YOLO_.pt_models_to_ONNX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #YOLOv8 ONNX conversion
# ![YOLOv8](https://raw.githubusercontent.com/ultralytics/assets/main/yolov8/banner-yolov8.png)

# %% [markdown]
# ## Convert model
# ❗If you don't have a Nvidia GPU, set `optimize_cpu=True` to optimize for CPU inference.

# %%
# !pip install ultralytics
from ultralytics import YOLO

model_name = 'yolov8m' #@param ["yolov8n", "yolov8s", "yolov8m", "yolov8l", "yolov8x"]
input_width = 640 #@param {type:"slider", min:32, max:4096, step:32}
input_height = 480 #@param {type:"slider", min:32, max:4096, step:32}
optimize_cpu = False

model = YOLO(f"{model_name}.pt")
model.export(format="onnx", imgsz=[input_height,input_width], optimize=optimize_cpu)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 513.5/513.5 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 kB 12.9 MB/s eta 0:00:00
# ...
# 100%|██████████| 5.27M/5.27M [00:01<00:00, 3.47MB/s]
# Ultralytics YOLOv8.0.78 🚀 Python-3.9.16 torch-2.0.0+cu118 CPU
# YOLOv5n summary (fused): 193 layers, 2649200 parameters, 0 gradients, 7.7 GFLOPs
#
# PyTorch: starting from yolov5nu.pt with input shape (1, 3, 480, 640) BCHW and output shape(s) (1, 84, 6300) (5.3 MB)
# requirements: YOLOv8 requirement "onnx>=1.12.0" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 305.9 MB/s eta 0:00:00
# ...
#
# requirements: 1 package updated per ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ...

# %% [markdown]
# ## Download model

# %%
# %cd /content
from google.colab import files

files.download(f'{model_name}.onnx')
# Out:
# /content
